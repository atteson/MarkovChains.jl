# %% [markdown]
# ### Read the data on the SPX index; the first column is the "total return" which incorporates corporate actions

# %%
lines = readlines("../data/sp.txt")
# Out:
# 24420-element Array{String,1}:
#  " "
#  "                                                                                                                                                                                                                                                                "
#  " "
#  "   caldt        vwretd        sprtrn      spindx"
#  ""
#  "19251231       .             .               .  "
#  "19260102      0.004297       .               .  "
#  "19260104     -0.001357       .               .  "
#  "19260105     -0.004603       .               .  "
#  "19260106      0.000537       .               .  "
#  "19260107      0.003907       .               .  "
#  "19260108     -0.002693       .               .  "
#  "19260109      0.002218       .               .  "
#  ⋮
#  "20180614      0.002792      0.002472     2782.49"
#  "20180615     -0.000889     -0.001017     2779.66"
#  "20180618     -0.002019     -0.002126     2773.75"
#  "20180619     -0.003911     -0.004023     2762.59"
#  "20180620      0.001673      0.001712     2767.32"
#  "20180621     -0.006173     -0.006345     2749.76"
#  "20180622      0.001880      0.001862     2754.88"
#  "20180625     -0.013623     -0.013725     2717.07"
#  "20180626      0.002201      0.002205     2723.06"
#  "20180627     -0.008636     -0.008604     2699.63"
#  "20180628      0.006236      0.006179     2716.31"
#  "20180629      0.000819      0.000758     2718.37"

# %% [markdown]
# ### Work out which row the data seems to start on

# %%
length.(lines)
# Out:
# 24420-element Array{Int64,1}:
#    1
#  256
#    1
#   48
#    0
#   48
#   48
#   48
#   48
#   48
#   48
#   48
#   48
#    ⋮
#   48
#   48
#   48
#   48
#   48
#   48
#   48
#   48
#   48
#   48
#   48
#   48

# %% [markdown]
# ### Check the intermediate rows

# %%
unique(length.(lines[6:end]))
# Out:
# 1-element Array{Int64,1}:
#  48

# %% [markdown]
# ### Isolate the first column

# %%
[line[14:22] for line in lines[7:end]]
# Out:
# 24414-element Array{String,1}:
#  " 0.004297"
#  "-0.001357"
#  "-0.004603"
#  " 0.000537"
#  " 0.003907"
#  "-0.002693"
#  " 0.002218"
#  "-0.006515"
#  "-0.001597"
#  " 0.003465"
#  "-0.005732"
#  "-0.012153"
#  "-0.000511"
#  ⋮
#  " 0.002792"
#  "-0.000889"
#  "-0.002019"
#  "-0.003911"
#  " 0.001673"
#  "-0.006173"
#  " 0.001880"
#  "-0.013623"
#  " 0.002201"
#  "-0.008636"
#  " 0.006236"
#  " 0.000819"

# %% [markdown]
# ### Parse the first column

# %%
returns = [parse(Float64,line[14:22]) for line in lines[7:end]]
# Out:
# 24414-element Array{Float64,1}:
#   0.004297
#  -0.001357
#  -0.004603
#   0.000537
#   0.003907
#  -0.002693
#   0.002218
#  -0.006515
#  -0.001597
#   0.003465
#  -0.005732
#  -0.012153
#  -0.000511
#   ⋮
#   0.002792
#  -0.000889
#  -0.002019
#  -0.003911
#   0.001673
#  -0.006173
#   0.00188
#  -0.013623
#   0.002201
#  -0.008636
#   0.006236
#   0.000819

# %% [markdown]
# ### Import some basic statistics functions

# %%
using StatsBase
# Out:
# ┌ Info: Precompiling StatsBase [2913bbd2-ae8a-5f71-8c99-4fb6c76f3a91]
# └ @ Base loading.jl:1186

# %% [markdown]
# ### Find cubile boundaries

# %%
(lo,hi) = StatsBase.quantile(returns,[1/3,2/3])
# Out:
# 2-element Array{Float64,1}:
#  -0.002208333333333334
#   0.003497666666666664

# %% [markdown]
# ### We'll use ```searchsorted``` to find which cubile each is in

# %%
[searchsorted([lo,hi],r) for r in returns]
# Out:
# 24414-element Array{UnitRange{Int64},1}:
#  3:2
#  2:1
#  1:0
#  2:1
#  3:2
#  1:0
#  2:1
#  1:0
#  2:1
#  2:1
#  1:0
#  1:0
#  2:1
#  ⋮
#  2:1
#  2:1
#  2:1
#  1:0
#  2:1
#  1:0
#  2:1
#  1:0
#  2:1
#  1:0
#  3:2
#  2:1

# %% [markdown]
# ### Searchsorted returns a range of indices where the element occurs in the list.  We want the first index.

# %%
cubiles = [searchsorted([lo,hi],r).start for r in returns]
# Out:
# 24414-element Array{Int64,1}:
#  3
#  2
#  1
#  2
#  3
#  1
#  2
#  1
#  2
#  2
#  1
#  1
#  2
#  ⋮
#  2
#  2
#  2
#  1
#  2
#  1
#  2
#  1
#  2
#  1
#  3
#  2

# %% [markdown]
# ### Estimate a Markov chain

# %%
n = [sum((cubiles[1:end-1].==i).&(cubiles[2:end].==j)) for i in 1:3, j in 1:3]
# Out:
# 3×3 Array{Int64,2}:
#  3146  2275  2717
#  2570  3123  2444
#  2422  2740  2976

# %% [markdown]
# ## The mean reversion that we previously saw in SPY doesn't occur for the larger dataset!!!

# %%
n ./ sum(n,dims=2)
# Out:
# 3×3 Array{Float64,2}:
#  0.386581  0.279553  0.333866
#  0.315841  0.383802  0.300356
#  0.297616  0.336692  0.365692

# %%
n = [sum((cubiles[end-25*252-1:end-1].==i).&(cubiles[end-25*252:end].==j)) for i in 1:3, j in 1:3]
# Out:
# 3×3 Array{Int64,2}:
#  730  528  858
#  642  750  620
#  743  735  695

# %%
n ./ sum(n,dims=2)
# Out:
# 3×3 Array{Float64,2}:
#  0.344991  0.249527  0.405482
#  0.319085  0.372763  0.308151
#  0.341924  0.338242  0.319834

# %%
lag = 4*252
n = [sum((cubiles[i-lag:i-1].==1).&(cubiles[i-lag+1:i].==3))/sum(cubiles[i-lag:i-1].==1) for i in lag+1:length(cubiles)]
# Out:
# 23406-element Array{Float64,1}:
#  0.35587188612099646
#  0.35587188612099646
#  0.35815602836879434
#  0.3594306049822064
#  0.35815602836879434
#  0.3568904593639576
#  0.36042402826855124
#  0.36042402826855124
#  0.3617021276595745
#  0.3617021276595745
#  0.3617021276595745
#  0.36298932384341637
#  0.36428571428571427
#  ⋮
#  0.38405797101449274
#  0.38405797101449274
#  0.38405797101449274
#  0.38405797101449274
#  0.38267148014440433
#  0.38267148014440433
#  0.381294964028777
#  0.381294964028777
#  0.3776978417266187
#  0.3776978417266187
#  0.37992831541218636
#  0.37992831541218636

# %%
using Plots
# Out:
# ┌ Info: Precompiling Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# └ @ Base loading.jl:1186

# %%
plot((1:length(n))/252, n, legend=false)

# %% [markdown]
# ### Test out the optimization package NLopt

# %%
Pkg.add("NLopt")
# Out:
#   Updating registry at `/home/jrun/.julia/registries/JuliaPro`
#   Updating git-repo `https://pkg.juliacomputing.com/registry/JuliaPro`
# Fetching: [========================================>]  100.0 %.0 % Resolving package versions...
#   Updating `~/.julia/Project.toml`
#  [no changes]
#   Updating `~/.julia/Manifest.toml`
#  [no changes]

# %%
using NLopt

# %%
function f(x::Vector{Float64}, g::Vector{Float64})
    g[1] = 2*(x[1]-1.0)
    g[2] = 2*(x[2]-2.0)
    return (x[1]-1.0)^2+(x[2]-2.0)^2
end
# Out:
# f (generic function with 1 method)

# %%
problem = Opt(:LD_MMA, 2)
# Out:
# Opt(LD_MMA, 2)

# %%
xtol_rel!(problem,1e-4)

# %%
min_objective!(problem,f)

# %%
(minf,minx,ret)=optimize(problem,zeros(2))
# Out:
# (9.803473164442314e-14, [1.0, 2.0], :XTOL_REACHED)

# %%
minx-[1.0,2.0]
# Out:
# 2-element Array{Float64,1}:
#  -2.6306580958035397e-7
#  -1.6979726580323984e-7

# %%
recentreturns = returns[end-25*252:end]
# Out:
# 6301-element Array{Float64,1}:
#   0.007971
#   0.002253
#   0.009565
#  -0.002813
#   0.000372
#  -0.003702
#  -0.006356
#  -0.009953
#   0.00323
#   0.012654
#  -0.000501
#   0.00164
#  -0.001721
#   ⋮
#   0.002792
#  -0.000889
#  -0.002019
#  -0.003911
#   0.001673
#  -0.006173
#   0.00188
#  -0.013623
#   0.002201
#  -0.008636
#   0.006236
#   0.000819

# %%
function f(w::Vector{Float64}, g::Vector{Float64})
    g[1] = sum(recentreturns ./ (1 .+ w[1] .* recentreturns))
    return sum(log.(1 .+ w[1] .* recentreturns))
end
# Out:
# f (generic function with 1 method)

# %%
problem = Opt(:LD_MMA,1)
# Out:
# Opt(LD_MMA, 1)

# %%
lower_bounds!(problem,[0.0])

# %%
upper_bounds!(problem,[10.0])

# %%
xtol_rel!(problem,1e-4)

# %%
max_objective!(problem,f)

# %%
(minf,minx,ret)=optimize(problem,[0.5])
# Out:
# (4.531214199895032, [3.29434], :XTOL_REACHED)

# %%
StatsBase.mean(log.(1 .+ minx[1]*recentreturns))*252
# Out:
# 0.18121980294771434

# %%
StatsBase.std(log.(1 .+ minx[1]*recentreturns))*sqrt(252)
# Out:
# 0.5991113376600778

# %%
recentreturns = returns[end-25*252-1:end]
(lo,hi) = StatsBase.quantile(recentreturns,[1/3,2/3])
cubiles = [searchsorted([lo,hi],r).start for r in recentreturns]
# Out:
# 6302-element Array{Int64,1}:
#  1
#  3
#  2
#  3
#  1
#  2
#  1
#  1
#  1
#  2
#  3
#  2
#  2
#  ⋮
#  2
#  2
#  2
#  1
#  2
#  1
#  2
#  1
#  2
#  1
#  3
#  2

# %%
cubilereturns = [recentreturns[2:end][cubiles[1:end-1].==i] for i in 1:3]
# Out:
# 3-element Array{Array{Float64,1},1}:
#  [0.007971, 0.000372, -0.006356, -0.009953, 0.00323, 0.000798, 0.005549, 0.004561, 0.00219, 0.002301  …  0.004428, 0.007425, 0.003406, 0.012907, 0.010939, 0.002792, 0.001673, 0.00188, 0.002201, 0.006236]
#  [0.009565, -0.003702, 0.012654, 0.00164, -0.001721, 0.00423, -0.007815, 0.002875, -0.000279, -0.006016  …  0.003144, 0.001203, 0.001815, -0.003889, -0.000889, -0.002019, -0.003911, -0.006173, -0.013623, -0.008636]
#  [0.002253, -0.002813, -0.000501, -0.001877, 0.004746, -0.001914, -0.004926, -0.001367, -0.002358, 0.002051  …  0.00338, 0.009527, 0.002118, -0.000679, -0.003195, -0.006667, 0.00478, 0.000747, -0.000615, 0.000819]

# %%
w3 = fill(NaN,3)
# Out:
# 3-element Array{Float64,1}:
#  NaN
#  NaN
#  NaN

# %%
function f1(w::Vector{Float64}, g::Vector{Float64})
    g[1] = sum(cubilereturns[1] ./ (1 .+ w[1] .* cubilereturns[1]))
    return sum(log.(1 .+ w[1] .* cubilereturns[1]))
end
# Out:
# f1 (generic function with 1 method)

# %%
problem = Opt(:LD_MMA,1)
lower_bounds!(problem,[0.0])
upper_bounds!(problem,[10.0])
xtol_rel!(problem,1e-4)
max_objective!(problem,f1)
(minf,w,ret)=optimize(problem,[0.5])
w3[1]=w[1]
# Out:
# 5.096805462450377

# %%
function f2(w::Vector{Float64}, g::Vector{Float64})
    g[1] = sum(cubilereturns[2] ./ (1 .+ w[1] .* cubilereturns[2]))
    return sum(log.(1 .+ w[1] .* cubilereturns[2]))
end
# Out:
# f2 (generic function with 1 method)

# %%
problem = Opt(:LD_MMA,1)
lower_bounds!(problem,[0.0])
upper_bounds!(problem,[10.0])
xtol_rel!(problem,1e-4)
max_objective!(problem,f2)
(minf,w,ret)=optimize(problem,[0.5])
w3[2]=w[1]
# Out:
# 0.5728522755172032

# %%
function f3(w::Vector{Float64}, g::Vector{Float64})
    g[1] = sum(cubilereturns[3] ./ (1 .+ w[1] .* cubilereturns[3]))
    return sum(log.(1 .+ w[1] .* cubilereturns[3]))
end
# Out:
# f3 (generic function with 1 method)

# %%
problem = Opt(:LD_MMA,1)
lower_bounds!(problem,[0.0])
upper_bounds!(problem,[10.0])
xtol_rel!(problem,1e-4)
max_objective!(problem,f3)
(minf,w,ret)=optimize(problem,[0.5])
w3[3]=w[1]
# Out:
# 2.3030772787131935

# %%
wr=[w3[cubiles[i]]*recentreturns[i+1] for i in 1:length(cubiles)-1]
# Out:
# 6301-element Array{Float64,1}:
#   0.040626636341191964
#   0.005188833108940825
#   0.005479332015322049
#  -0.0064785563850202135
#   0.0018960116320315403
#  -0.0021206991239646864
#  -0.032395295519334594
#  -0.050728504767768606
#   0.016462681643714717
#   0.007248872694394689
#  -0.00115384171663531
#   0.0009394777318482132
#  -0.0009858787661651068
#   ⋮
#   0.014230280851161455
#  -0.0005092656729347937
#  -0.0011565887442692333
#  -0.002240425249547782
#   0.008526955538679482
#  -0.003536217096767695
#   0.009581994269406709
#  -0.0078039665493708586
#   0.01121806882285328
#  -0.004947152251366566
#   0.03178367886384056
#   0.0018862202912661053

# %%
StatsBase.mean(log.(1 .+ wr))*252
# Out:
# 0.23992984025305267

# %%
StatsBase.std(log.(1 .+ wr))*sqrt(252)
# Out:
# 0.6858815650160024

# %%
plot((1:length(wr))/252, cumprod(1 .+ wr), legend=false)

# %%
plot!((1:length(recentreturns[2:end]))/252,cumprod(1 .+ minx[1] .* recentreturns[2:end]), legend=false)

# %%
plot!(yscale=:log)

# %%
states = [(cubiles[i-2]-1)*3+cubiles[i-1] for i in 3:length(cubiles)]
# Out:
# 6300-element Array{Int64,1}:
#  3
#  8
#  6
#  7
#  2
#  4
#  1
#  1
#  2
#  6
#  8
#  5
#  5
#  ⋮
#  4
#  2
#  5
#  5
#  4
#  2
#  4
#  2
#  4
#  2
#  4
#  3

# %%
function f(w::Vector{Float64}, g::Vector{Float64}, r::Vector{Float64})
    g[1] = sum(r ./ (1 .+ w[1] .* r))
    return sum(log.(1 .+ w[1] .* r)) 
end
# Out:
# f (generic function with 2 methods)

# %%
function findw(r::Vector{Float64})
    problem = Opt(:LD_MMA,1)
    lower_bounds!(problem,[-10.0])
    upper_bounds!(problem,[10.0])
    xtol_rel!(problem,1e-4)
    max_objective!(problem,(w,g)->f(w,g,r))
    (minf,w,ret)=optimize(problem,[0.5])
    return w
end
# Out:
# findw (generic function with 1 method)

# %%
w9 = fill(NaN,9)
for i = 1:9
    w9[i]=findw(recentreturns[3:end][states.==i])[1]
end

# %%
w9
# Out:
# 9-element Array{Float64,1}:
#   7.409664091023799
#  -3.317856778040025
#   3.58405670036354
#   6.129810621999355
#   0.3221538700941963
#   6.426458381738242
#   0.8122711730515314
#   4.466844891831409
#  -2.741071303037823

# %%
wr = [w9[states[i]]*recentreturns[3:end][i] for i in 1:length(states)]
# Out:
# 6300-element Array{Float64,1}:
#   0.008074879745919054
#   0.042725371390367424
#  -0.018077627427829673
#   0.00030216487637516965
#   0.012282705792304173
#  -0.0389610763134279
#  -0.07374838669795987
#   0.02393321501400687
#  -0.04198415966931848
#  -0.0032196556492508593
#   0.00732562562260351
#  -0.0005544268104321119
#   0.0013627108704984505
#   ⋮
#   0.017114431256622202
#   0.0029495746756775824
#  -0.0006504286637201823
#  -0.001259943785938402
#   0.010255173170604922
#   0.020481129890841075
#   0.011524043969358787
#   0.04519916288723926
#   0.01349171317902058
#   0.028653011135153655
#   0.03822549903878798
#   0.002935342437597739

# %%
StatsBase.mean(wr)*252
# Out:
# 0.8003338488827816

# %%
StatsBase.std(wr)*sqrt(252)
# Out:
# 0.8826401968777605

# %%
plot((1:length(wr))/252, cumprod(1 .+ wr), legend=false)

# %%
lag = 10*252
for i = 1:25
    trainingdata = returns[end+(year-27)*252:end+(year-26)*252-1]
# Out:
# 6302

# %%
StatsBase.mean(wr)
# Out:
# 0.0022452945361992327

# %%
prod( 1 .+ wr )
# Out:
# 0.059556378130626655

# %%
lag=25*252
wr = Float64[]
for year = 1:25
    trainingdata = returns[end+(year-26)*252-lag+1:end+(year-26)*252]
    (lo,hi) = StatsBase.quantile(trainingdata,[1/3,2/3])
    trainingcubiles = [searchsorted([lo,hi],r).start for r in trainingdata[1:end-1]]
    w = fill(NaN,3)
    for i = 1:3
        w[i] = findw(trainingdata[2:end][trainingcubiles.==i])[1]
    end 

    statedata = returns[end+(year-26)*252:end+(year-25)*252-1]
    statecubiles = [searchsorted([lo,hi],r).start for r in statedata]

    testdata = returns[end+(year-26)*252+1:end+(year-25)*252]
    wr = vcat(wr, [w[statecubiles[i]]*testdata[i] for i in 1:length(testdata)])
end

# %%
wr
# Out:
# 6300-element Array{Float64,1}:
#   0.022529999999999998
#   0.07743389774242805
#  -0.02813
#  -0.0037199999999999998
#  -0.02996971138969876
#   0.06355999999999999
#   0.09953000000000001
#  -0.032299999999999995
#   0.10244103941794924
#  -0.0050100000000000006
#   0.01327669548328092
#  -0.013932434711418576
#   0.03424415969163311
#   ⋮
#   0.014106716178366976
#  -0.000672494302450546
#  -0.0015272958342493277
#  -0.0029585210538628634
#   0.008452914099716314
#  -0.004669637040525557
#   0.009498791696035068
#  -0.010305275458136995
#   0.01112065985264531
#  -0.006532801795233875
#   0.0315076941576993
#   0.0018799562548840487

# %%
length(wr)
# Out:
# 6300

# %%
StatsBase.mean(log.(1 .+ wr))*252
# Out:
# -0.2979343993513561

# %%
StatsBase.std(log.(1 .+ wr))*sqrt(252)
# Out:
# 1.0473457253524823

# %%
plot((1:length(wr))/252, cumprod(1 .+ wr), legend=false, yscale=:log)
# Out:
# ┌ Warning: scale log is unsupported with Plots.GRBackend().  Choose from: Symbol[:identity, :log10]
# └ @ Plots /home/jrun/.julia/packages/Plots/7o1Vu/src/args.jl:1169

# %%
lag=25*252
wr = Float64[]
for year = 1:25
    trainingdata = returns[end+(year-26)*252-lag+1:end+(year-26)*252]
    (lo,hi) = StatsBase.quantile(trainingdata,[1/3,2/3])
    trainingcubiles = [searchsorted([lo,hi],r).start for r in trainingdata]
    trainingstates = [(trainingcubiles[i-1]-1)*3 + trainingcubiles[i] for i in 2:length(trainingcubiles)-1]
    w = fill(NaN,9)
    for i = 1:9
        w[i] = findw(trainingdata[3:end][trainingstates.==i])[1]
    end 

    statedata = returns[end+(year-26)*252-1:end+(year-25)*252-1]
    statecubiles = [searchsorted([lo,hi],r).start for r in statedata]
    states = [(statecubiles[i-1]-1)*3 + statecubiles[i] for i in 2:length(statecubiles)]

    testdata = returns[end+(year-26)*252+1:end+(year-25)*252]
    wr = vcat(wr, [w[states[i]]*testdata[i] for i in 1:length(testdata)])
end

# %%
length(wr)
# Out:
# 6300

# %%
StatsBase.mean(log.(1 .+ wr))*252
# Out:
# -0.32443801888670765

# %%
StatsBase.std(log.(1 .+ wr))*sqrt(252)
# Out:
# 1.1376049186891557

# %%
plot((1:length(wr))/252, cumprod(1 .+ wr), legend=false, yscale=:log)
# Out:
# ┌ Warning: scale log is unsupported with Plots.GRBackend().  Choose from: Symbol[:identity, :log10]
# └ @ Plots /home/jrun/.julia/packages/Plots/7o1Vu/src/args.jl:1169
